# %%
import pandas as pd

# %%
cf = pd.read_pickle('county_facts_with_2012_winner')

# %%
train_data = cf


X = train_data
forest = RandomForestClassifier(n_estimators = 100)
forest = forest.fit(X, targetClass)
output = forest.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d34021b67420> in <module>()
#       3
#       4 X = train_data
# ----> 5 forest = RandomForestClassifier(n_estimators = 100)
#       6 forest = forest.fit(X, targetClass)
#       7 output = forest.predict(test_data)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
primaryResults = pd.read_csv('../2016_presidential_election_v5/primary_results.csv')

# %%
primaryResults
# Out:
#                state state_abbreviation      county   fips       party  \
# 0            Alabama                 AL     Autauga   1001  Republican
# 1            Alabama                 AL     Autauga   1001  Republican
# 2            Alabama                 AL     Autauga   1001  Republican
# 3            Alabama                 AL     Autauga   1001  Republican
# 4            Alabama                 AL     Autauga   1001  Republican
# 5            Alabama                 AL     Autauga   1001    Democrat
# 6            Alabama                 AL     Autauga   1001    Democrat
# 7            Alabama                 AL     Baldwin   1003  Republican
# 8            Alabama                 AL     Baldwin   1003  Republican
# 9            Alabama                 AL     Baldwin   1003  Republican
# 10           Alabama                 AL     Baldwin   1003  Republican
# 11           Alabama                 AL     Baldwin   1003  Republican
# ...
